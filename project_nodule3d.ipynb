# %%
# !pip install libauc==1.2.0
# !pip install medmnist
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting libauc==1.2.0
#   Downloading libauc-1.2.0-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from libauc==1.2.0) (0.19.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from libauc==1.2.0) (1.5.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from libauc==1.2.0) (8.4.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from libauc==1.2.0) (4.7.0.72)
# Requirement already satisfied: torch>=1.2 in /usr/local/lib/python3.10/dist-packages (from libauc==1.2.0) (2.0.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from libauc==1.2.0) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from libauc==1.2.0) (1.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.2->libauc==1.2.0) (1.11.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.2->libauc==1.2.0) (4.5.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.2->libauc==1.2.0) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.2->libauc==1.2.0) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.2->libauc==1.2.0) (3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.2->libauc==1.2.0) (3.12.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.2->libauc==1.2.0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.2->libauc==1.2.0) (16.0.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->libauc==1.2.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->libauc==1.2.0) (2022.7.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->libauc==1.2.0) (2023.4.12)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->libauc==1.2.0) (23.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->libauc==1.2.0) (1.10.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->libauc==1.2.0) (2.25.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->libauc==1.2.0) (1.4.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->libauc==1.2.0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->libauc==1.2.0) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->libauc==1.2.0) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.2->libauc==1.2.0) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.2->libauc==1.2.0) (1.3.0)
# Installing collected packages: libauc
# Successfully installed libauc-1.2.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting medmnist
#   Downloading medmnist-2.2.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from medmnist) (0.19.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from medmnist) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from medmnist) (0.15.1+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from medmnist) (1.22.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from medmnist) (8.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from medmnist) (1.5.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from medmnist) (1.2.2)
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 11.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from medmnist) (4.65.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire->medmnist) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->medmnist) (2.3.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->medmnist) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->medmnist) (2.8.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (1.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (2023.4.12)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (23.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (3.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (2.25.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->medmnist) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->medmnist) (3.1.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (1.11.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (3.12.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (3.1.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->medmnist) (16.0.2)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->medmnist) (3.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision->medmnist) (2.27.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->medmnist) (2.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->medmnist) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->medmnist) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->medmnist) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->medmnist) (2.0.12)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->medmnist) (1.3.0)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116952 sha256=6015f4a8f02cc7fca8953fdac07d78e9ec6043ec99daa77768a5915c4897eed9
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# Installing collected packages: fire, medmnist
# Successfully installed fire-0.5.0 medmnist-2.2.1

# %%
import libauc;
import numpy as np
import pandas as pd
from medmnist import NoduleMNIST3D

from libauc.models import resnet18
from libauc.losses import AUCMLoss, CrossEntropyLoss
from libauc.optimizers import PESG, Adam
from libauc.utils import ImbalancedDataGenerator
from libauc.sampler import DualSampler  # data resampling (for binary class)
from libauc.metrics import auc_roc_score

import random
import scipy
from scipy.ndimage import rotate
from scipy import ndimage
from scipy.ndimage.filters import gaussian_filter
from scipy.ndimage import zoom

import torch 
from PIL import Image
import torchvision.transforms as transforms
from torch.utils.data import Dataset
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

from torch.optim.lr_scheduler import ReduceLROnPlateau, CosineAnnealingLR

import warnings
warnings.filterwarnings("ignore")
SEED=123
# Out:
# <ipython-input-2-29df3e0e74d7>:17: DeprecationWarning: Please use `gaussian_filter` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import gaussian_filter

# %%
'''
Adapted from kuangliu/pytorch-cifar .
'''

import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        # self.bn1 = nn.GroupNorm(num_groups=2, num_channels=planes)
        
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        # self.bn2 = nn.GroupNorm(num_groups=2, num_channels=planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
                # nn.GroupNorm(num_groups=2, num_channels=self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        # self.bn1 = nn.GroupNorm(num_groups=2, num_channels=planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        # self.bn2 = nn.GroupNorm(num_groups=2, num_channels=planes)
        self.conv3 = nn.Conv2d(planes, self.expansion *
                               planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)
        # self.bn3 = nn.GroupNorm(num_groups=2, num_channels=self.expansion*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
                # nn.GroupNorm(num_groups=2, num_channels=self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, in_channels=1, num_classes=2):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(in_channels, 64, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        # self.bn1 = nn.GroupNorm(num_groups=2, num_channels=64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        # out = F.avg_pool2d(out, 4)
        # out = F.adaptive_avg_pool3d(out, output_size=4)
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18(in_channels, num_classes):
    return ResNet(BasicBlock, [2, 2, 2, 2], in_channels=in_channels, num_classes=num_classes)


def ResNet50(in_channels, num_classes):
    return ResNet(Bottleneck, [3, 4, 6, 3], in_channels=in_channels, num_classes=num_classes)

# %%
train_npz=NoduleMNIST3D(split="train", download=True)
val_npz=NoduleMNIST3D(split="val", download=True)
test_npz=NoduleMNIST3D(split="test", download=True)
# Out:
# Downloading https://zenodo.org/record/6496656/files/nodulemnist3d.npz?download=1 to /root/.medmnist/nodulemnist3d.npz
# 100%|██████████| 29299364/29299364 [00:38<00:00, 753962.69it/s]
# Using downloaded and verified file: /root/.medmnist/nodulemnist3d.npz
# Using downloaded and verified file: /root/.medmnist/nodulemnist3d.npz

# %%
# train_npz=ChestMNIST(split="train", download=True)
# val_npz=ChestMNIST(split="val", download=True)
# test_npz=ChestMNIST(split="test", download=True)

# %%
train_npz
# Out:
# Dataset NoduleMNIST3D (nodulemnist3d)
#     Number of datapoints: 1158
#     Root location: /root/.medmnist
#     Split: train
#     Task: binary-class
#     Number of channels: 1
#     Meaning of labels: {'0': 'benign', '1': 'malignant'}
#     Number of samples: {'train': 1158, 'val': 165, 'test': 310}
#     Description: The NoduleMNIST3D is based on the LIDC-IDRI, a large public lung nodule dataset, containing images from thoracic CT scans. The dataset is designed for both lung nodule segmentation and 5-level malignancy classification task. To perform binary classification, we categorize cases with malignancy level 1/2 into negative class and 4/5 into positive class, ignoring the cases with malignancy level 3. We split the source dataset with a ratio of 7:1:2 into training, validation and test set, and center-crop the spatially normalized images (with a spacing of 1mm×1mm×1mm) into 28×28×28.
#     License: CC BY 4.0

# %%
def gaussian_blur_3d(img):
    random.seed(SEED)
    sigma = random.uniform(0.1,0.9)
    blurred = gaussian_filter(img, sigma=sigma)
    return blurred

# %%
def x_flip(img):
    random.seed(SEED)
    flipped = img[:, :, ::-1]
    return flipped

# %%
def y_flip(img):
    random.seed(SEED)
    flipped = img[:, ::-1, :]
    return flipped

# %%
def zoom_xy(img, min_zoom, max_zoom):
    random.seed(SEED)
    zoom_factor = random.uniform(min_zoom, max_zoom)
    h, w = img.shape[0], img.shape[1]

    # For multichannel images we don't want to apply the zoom factor to the RGB
    # dimension, so instead we create a tuple of zoom factors, one per array
    # dimension, with 1's for any trailing dimensions after the width and height.
    zoom_tuple = (1, zoom_factor, zoom_factor)

    # Zooming out
    if zoom_factor < 1:

        # Bounding box of the zoomed-out image within the output array
        zh = int(np.round(h * zoom_factor))
        zw = int(np.round(w * zoom_factor))
        top = (h - zh) // 2
        left = (w - zw) // 2

        # Zero-padding
        out = np.zeros_like(img)
        zoomed_img = zoom(img, zoom_tuple, order=0)
        #print(f"zoomed shape: {zoomed_img.shape}")
        #print(f"out shape:{out.shape}")
        #print(f"w:{w},h:{h},l:{left},t:{top},zw:{zw}, zh:{zh}")
        out[:, top:top+zh, left:left+zw] = zoomed_img

    # Zooming in
    elif zoom_factor > 1:

        # Bounding box of the zoomed-in region within the input array
        zh = int(np.ceil(h / zoom_factor))
        zw = int(np.ceil(w / zoom_factor))
        top = (h - zh) // 2
        left = (w - zw) // 2

        #out_template = np.zeros_like(img)
        out = zoom(img[:, top:top+zh, left:left+zw], zoom_tuple, order=0)
        #print(f"out shape:{out.shape}")
        #print(f"w:{w},h:{h},l:{left},t:{top},zw:{zw}, zh:{zh}")

        # `out` might still be slightly larger than `img` due to rounding, so
        # trim off any extra pixels at the edges
        trim_top = ((out.shape[1] - h) // 2)
        trim_left = ((out.shape[2] - w) // 2)
        #print(f"out shape before:{out.shape}")
        out = out[:, trim_top:trim_top+h, trim_left:trim_left+w]
        #print(f"out shape after:{out.shape}")
        #print(f"w:{w},h:{h},l:{left},trimtop:{trim_top},trimleft:{trim_left}")

    # If zoom_factor == 1, just return the input array
    else:
        out = img
    #print(out.shape)
    return out

# %%
def random_rotation_3d(img, min_angle, max_angle):
    """ Randomly rotate an image by a random angle (-max_angle, max_angle).

    Arguments:
    max_angle: `float`. The maximum rotation angle.

    Returns:
    rotated 3D image
    """
    random.seed(SEED)
    img_rot = np.zeros(img.shape)
    angle = random.uniform(min_angle, max_angle)
    if random.randint(1,100) > 50:
        #in half the cases, rotate left. in other half, rotate right.
        angle *= -1
        # Following lines would rotate on z and y axis as well, but not using them in this kernel
#        # rotate along z-axis
#        image2 = scipy.ndimage.interpolation.rotate(image1, angle, mode='nearest', axes=(0, 1), reshape=False)
#        # rotate along y-axis
#        image3 = scipy.ndimage.interpolation.rotate(image2, angle, mode='nearest', axes=(0, 2), reshape=False)

    # rotate along x-axis
    img_rot = scipy.ndimage.interpolation.rotate(img, angle, mode='nearest', axes=(1, 2), reshape=False)
    return img_rot.reshape(img.shape)

# %%
def img_augment_3d(X_train,y_train):
      my_img=X_train
      my_label=y_train
      for i in range(0,X_train.shape[0]):
        img=X_train[i]
        img1 = gaussian_blur_3d(img)
        my_img=np.append(my_img,np.expand_dims(img1,axis=0),axis=0)
      my_label=np.append(my_label,y_train,axis=0)
      print("done")
      for i in range(0,X_train.shape[0]):
        img=X_train[i]
        img1 = x_flip(img)
        my_img=np.append(my_img,np.expand_dims(img1,axis=0),axis=0)
      my_label=np.append(my_label,y_train,axis=0)
      print("done")
      for i in range(0,X_train.shape[0]):
        img=X_train[i]
        img1 = y_flip(img)
        my_img=np.append(my_img,np.expand_dims(img1,axis=0),axis=0)
      my_label=np.append(my_label,y_train,axis=0)

      for i in range(0,X_train.shape[0]):
        img=X_train[i]
        img1 = random_rotation_3d(img, 1, 10)
        my_img=np.append(my_img,np.expand_dims(img1,axis=0),axis=0)
      my_label=np.append(my_label,y_train,axis=0)

      for i in range(0,X_train.shape[0]):
        img=X_train[i]
        img1 = zoom_xy(img, 0.9, 1.1)
        my_img=np.append(my_img,np.expand_dims(img1,axis=0),axis=0)
      my_label=np.append(my_label,y_train,axis=0)
    
      return my_img,my_label

# %%
X_train=train_npz.imgs
y_train=train_npz.labels

X_val=val_npz.imgs
y_val=val_npz.labels

X_test=test_npz.imgs
y_test=test_npz.labels

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
# Out:
# (1158, 28, 28, 28)
# (1158, 1)
# (165, 28, 28, 28)
# (165, 1)

# %%
X_train,y_train=img_augment_3d(X_train,y_train)
# Out:
# done
# done

# %%
class ImageDataset(Dataset):
    def __init__(self, images, targets, image_size=28, crop_size=26, mode='train'):
       self.images = images.astype(np.uint8)
       self.targets = targets
       self.mode = mode
       self.transform_train = transforms.Compose([                                               
                              transforms.ToTensor(),
                              # transforms.RandomCrop((crop_size, crop_size, crop_), padding=None),
                              # transforms.RandomHorizontalFlip(),
                              # transforms.Resize((image_size, image_size, image_size)),
                              ])
       self.transform_test = transforms.Compose([
                             transforms.ToTensor(),
                            #  transforms.Resize((image_size, image_size, image_size)),
                              ])
       
       # for loss function
       self.pos_indices = np.flatnonzero(targets==1)
       self.pos_index_map = {}
       for i, idx in enumerate(self.pos_indices):
           self.pos_index_map[idx] = i

    def __len__(self):
        # print(len(self.images))
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        target = self.targets[idx]
        if self.mode == 'train':
            idx = self.pos_index_map[idx] if idx in self.pos_indices else -1
            image = self.transform_train(image)
            # print(type(image))
        else:
            image = self.transform_test(image)
            # print(type(image))
        return image, target, int(idx)

# %%
def set_all_seeds(SEED):
    # REPRODUCIBILITY
    torch.manual_seed(SEED)
    np.random.seed(SEED)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
# HyperParameters
SEED = 123
batch_size = 64
total_epochs = 40
decay_epochs = [50, 75]

lr = 0.1
margin = 1.0
epoch_decay = 0.003 # refers gamma in the paper
weight_decay = 0.0001

# oversampling minority class, you can tune it in (0, 0.5]
# e.g., sampling_rate=0.2 is that num of positive samples in mini-batch is sampling_rate*batch_size=13
sampling_rate = 0.2

# %%
imratio = 0.5
generator = ImbalancedDataGenerator(shuffle=True, verbose=True, random_seed=0)

(train_images, train_labels) = generator.transform(X_train, y_train, imratio=imratio)
(eval_images, eval_labels) = generator.transform(X_val, y_val, imratio=imratio)
(test_images, test_labels) = generator.transform(X_test, y_test, imratio=0.5) 

print((train_images.shape))
print((eval_images.shape))
print((test_images.shape))
trainSet = ImageDataset(train_images, train_labels)
evalSet = ImageDataset(eval_images, eval_labels)
testSet = ImageDataset(test_images, test_labels, mode='test')

sampler = DualSampler(trainSet, batch_size, sampling_rate=sampling_rate)
trainloader = torch.utils.data.DataLoader(trainSet, batch_size=batch_size,  sampler=sampler,  shuffle=False,  num_workers=1)
evalloader = torch.utils.data.DataLoader(evalSet, batch_size=batch_size,  shuffle=False,  num_workers=1)
testloader = torch.utils.data.DataLoader(testSet , batch_size=batch_size, shuffle=False, num_workers=1)
# Out:
# #SAMPLES: [6948], POS:NEG: [1770 : 5178], POS RATIO: 0.2547
# #SAMPLES: [165], POS:NEG: [42 : 123], POS RATIO: 0.2545
# #SAMPLES: [310], POS:NEG: [64 : 246], POS RATIO: 0.2065
# (6948, 28, 28, 28)
# (165, 28, 28, 28)
# (310, 28, 28, 28)

# %%
# model
set_all_seeds(SEED)
# model = resnet18(pretrained=False, num_classes=1, last_activation=None) 
model = ResNet18(in_channels = 28, num_classes= 2)

model = model.cuda()
lr =0.1
# You can also pass Loss.a, Loss.b, Loss.alpha to optimizer (for old version users)
loss_fn = AUCMLoss()
optimizer = PESG(model, 
                 loss_fn=loss_fn,
                 lr=lr, 
                 momentum=0.9,
                 margin=margin,
                 epoch_decay=epoch_decay, 
                 weight_decay=weight_decay)

scheduler1 =  ReduceLROnPlateau(optimizer, 'min', patience=2)
# scheduler2 = CosineAnnealingLR(optimizer, T_max = 20)
# model

# %%
print(evalloader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7fe53a585150>

# %%
# print ('Start Training')
# print ('-'*30)

# ckpt =  torch.load("Epoch_nextrun: 20")
# model.load_state_dict(ckpt)
# train_log = []
# test_log = []
# for epoch in range(total_epochs):
#      if epoch in decay_epochs:
#          optimizer.update_regularizer(decay_factor=10) # decrease learning rate by 10x & update regularizer
   
#      train_loss = []
#      model.train() 
#      for data, targets, _ in trainloader:
#          data, targets  = data.cuda(), targets.cuda()
#          y_pred = model(data)
#          y_pred = torch.sigmoid(y_pred)
#          loss = loss_fn(y_pred, targets)
#          optimizer.zero_grad()
#          loss.backward()
#          optimizer.step()
#          train_loss.append(loss.item())
#      if epoch % 5 == 0:
#        torch.save(model.state_dict(), "Epoch: {}".format(epoch))
#        print("Saving model for epoch number: {}".format(epoch))

#      model.eval()
#      train_pred_list = []
#      train_true_list = []
#      for train_data, train_targets,_ in evalloader:
#          train_data = train_data.cuda()
#          train_pred = model(train_data)
#          train_pred_list.append(train_pred.cpu().detach().numpy())
#          train_true_list.append(train_targets.numpy())
#      train_true = np.concatenate(train_true_list)
#      train_pred = np.concatenate(train_pred_list)
#      train_auc = auc_roc_score(train_true, train_pred)
#      train_loss = np.mean(train_loss)
#      scheduler1.step(train_loss)
#      # evaluation on train & test sets
     

#      # Take this loop out once model is done
#      test_pred_list = []
#      test_true_list = [] 
#      for test_data, test_targets,_ in testloader:
#          test_data = test_data.cuda()
#          test_pred = model(test_data)
#          test_pred_list.append(test_pred.cpu().detach().numpy())
#          test_true_list.append(test_targets.numpy())
#      test_true = np.concatenate(test_true_list)
#      test_pred = np.concatenate(test_pred_list)
#      test_auc =  auc_roc_score(test_true, test_pred) 
#      model.train()
 
#      # print results
#      print("epoch: %s, train_loss: %.4f, train_auc: %.4f, test_auc: %.4f, lr: %.4f"%(epoch, train_loss, val_auc[0], test_auc[0], optimizer.lr )) 
#      train_log.append(train_auc) 
#      test_log.append(val_auc)

# %%
# training
print ('Start Training')
print ('-'*30)

best_val_auc = 0 
for epoch in range(total_epochs):
    # if epoch % 10 == 0:
    #     optimizer.update_regularizer(decay_factor=2)    

    for idx, (data, targets, _) in enumerate(trainloader):
      train_data, train_labels = data, targets
      train_data, train_labels  = train_data.cuda(), train_labels.cuda()
      y_pred = model(train_data)
      y_pred = torch.sigmoid(y_pred)
      loss = loss_fn(y_pred, train_labels)
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      # scheduler1.step(loss)
      # torch.save(model.state_dict(), "Epoch: {}".format(epoch))
      # print("Saving model for epoch number: {}".format(epoch))

        
      # validation  
      if idx % 20 == 0:
         model.eval()
         with torch.no_grad():    
              test_pred = []
              test_true = [] 
              for jdx, (data, targets, _) in enumerate(testloader):
                  test_data, test_labels = data, targets
                  test_data = test_data.cuda()
                  y_pred = model(test_data)
                  y_pred = torch.sigmoid(y_pred)
                  test_pred.append(y_pred.cpu().detach().numpy())
                  test_true.append(test_labels.numpy())
            
              test_true = np.concatenate(test_true)
              test_pred = np.concatenate(test_pred)
              val_auc_mean = auc_roc_score(test_true, test_pred)[0] 
              model.train()

              if best_val_auc < val_auc_mean:
                 best_val_auc = val_auc_mean
                 torch.save(model.state_dict(), 'nodule_model.pt')

              print ('Epoch=%s, BatchID=%s, Val_AUC=%.4f, Best_Val_AUC=%.4f'%(epoch, idx, val_auc_mean, best_val_auc))
# Out:
# Start Training
# ------------------------------
# Epoch=0, BatchID=0, Val_AUC=0.8390, Best_Val_AUC=0.8390
# Epoch=0, BatchID=20, Val_AUC=0.8670, Best_Val_AUC=0.8670
# Epoch=0, BatchID=40, Val_AUC=0.8539, Best_Val_AUC=0.8670
# Epoch=0, BatchID=60, Val_AUC=0.8684, Best_Val_AUC=0.8684
# Epoch=0, BatchID=80, Val_AUC=0.8683, Best_Val_AUC=0.8684
# Epoch=0, BatchID=100, Val_AUC=0.8484, Best_Val_AUC=0.8684
# Epoch=0, BatchID=120, Val_AUC=0.8509, Best_Val_AUC=0.8684
# Epoch=0, BatchID=140, Val_AUC=0.8841, Best_Val_AUC=0.8841
# Epoch=1, BatchID=0, Val_AUC=0.8732, Best_Val_AUC=0.8841
# Epoch=1, BatchID=20, Val_AUC=0.8733, Best_Val_AUC=0.8841
# Epoch=1, BatchID=40, Val_AUC=0.8549, Best_Val_AUC=0.8841
# Epoch=1, BatchID=60, Val_AUC=0.8540, Best_Val_AUC=0.8841
# Epoch=1, BatchID=80, Val_AUC=0.8655, Best_Val_AUC=0.8841
# Epoch=1, BatchID=100, Val_AUC=0.8545, Best_Val_AUC=0.8841
# Epoch=1, BatchID=120, Val_AUC=0.8673, Best_Val_AUC=0.8841
# Epoch=1, BatchID=140, Val_AUC=0.8582, Best_Val_AUC=0.8841
# Epoch=2, BatchID=0, Val_AUC=0.8620, Best_Val_AUC=0.8841
# Epoch=2, BatchID=20, Val_AUC=0.8574, Best_Val_AUC=0.8841
# Epoch=2, BatchID=40, Val_AUC=0.8638, Best_Val_AUC=0.8841
# Epoch=2, BatchID=60, Val_AUC=0.8357, Best_Val_AUC=0.8841
# Epoch=2, BatchID=80, Val_AUC=0.8555, Best_Val_AUC=0.8841
# Epoch=2, BatchID=100, Val_AUC=0.8488, Best_Val_AUC=0.8841
# Epoch=2, BatchID=120, Val_AUC=0.8714, Best_Val_AUC=0.8841
# Epoch=2, BatchID=140, Val_AUC=0.8687, Best_Val_AUC=0.8841
# Epoch=3, BatchID=0, Val_AUC=0.8735, Best_Val_AUC=0.8841
# Epoch=3, BatchID=20, Val_AUC=0.8639, Best_Val_AUC=0.8841
# Epoch=3, BatchID=40, Val_AUC=0.8643, Best_Val_AUC=0.8841
# Epoch=3, BatchID=60, Val_AUC=0.8604, Best_Val_AUC=0.8841
# Epoch=3, BatchID=80, Val_AUC=0.8421, Best_Val_AUC=0.8841
# Epoch=3, BatchID=100, Val_AUC=0.8502, Best_Val_AUC=0.8841
# Epoch=3, BatchID=120, Val_AUC=0.8746, Best_Val_AUC=0.8841
# Epoch=3, BatchID=140, Val_AUC=0.8777, Best_Val_AUC=0.8841
# Epoch=4, BatchID=0, Val_AUC=0.8656, Best_Val_AUC=0.8841
# Epoch=4, BatchID=20, Val_AUC=0.8616, Best_Val_AUC=0.8841
# Epoch=4, BatchID=40, Val_AUC=0.8732, Best_Val_AUC=0.8841
# Epoch=4, BatchID=60, Val_AUC=0.8690, Best_Val_AUC=0.8841
# Epoch=4, BatchID=80, Val_AUC=0.8666, Best_Val_AUC=0.8841
# Epoch=4, BatchID=100, Val_AUC=0.8717, Best_Val_AUC=0.8841
# Epoch=4, BatchID=120, Val_AUC=0.8521, Best_Val_AUC=0.8841
# Epoch=4, BatchID=140, Val_AUC=0.8671, Best_Val_AUC=0.8841
# Epoch=5, BatchID=0, Val_AUC=0.8620, Best_Val_AUC=0.8841
# Epoch=5, BatchID=20, Val_AUC=0.8529, Best_Val_AUC=0.8841
# Epoch=5, BatchID=40, Val_AUC=0.8575, Best_Val_AUC=0.8841
# Epoch=5, BatchID=60, Val_AUC=0.8760, Best_Val_AUC=0.8841
# Epoch=5, BatchID=80, Val_AUC=0.8817, Best_Val_AUC=0.8841
# Epoch=5, BatchID=100, Val_AUC=0.8658, Best_Val_AUC=0.8841
# Epoch=5, BatchID=120, Val_AUC=0.8435, Best_Val_AUC=0.8841
# Epoch=5, BatchID=140, Val_AUC=0.8603, Best_Val_AUC=0.8841
# Epoch=6, BatchID=0, Val_AUC=0.8496, Best_Val_AUC=0.8841
# Epoch=6, BatchID=20, Val_AUC=0.8607, Best_Val_AUC=0.8841
# Epoch=6, BatchID=40, Val_AUC=0.8410, Best_Val_AUC=0.8841
# Epoch=6, BatchID=60, Val_AUC=0.8771, Best_Val_AUC=0.8841
# Epoch=6, BatchID=80, Val_AUC=0.8568, Best_Val_AUC=0.8841
# Epoch=6, BatchID=100, Val_AUC=0.8276, Best_Val_AUC=0.8841
# Epoch=6, BatchID=120, Val_AUC=0.8406, Best_Val_AUC=0.8841
# Epoch=6, BatchID=140, Val_AUC=0.8630, Best_Val_AUC=0.8841
# Epoch=7, BatchID=0, Val_AUC=0.8769, Best_Val_AUC=0.8841
# Epoch=7, BatchID=20, Val_AUC=0.8840, Best_Val_AUC=0.8841
# Epoch=7, BatchID=40, Val_AUC=0.8737, Best_Val_AUC=0.8841
# Epoch=7, BatchID=60, Val_AUC=0.8329, Best_Val_AUC=0.8841
# Epoch=7, BatchID=80, Val_AUC=0.8641, Best_Val_AUC=0.8841
# Epoch=7, BatchID=100, Val_AUC=0.8735, Best_Val_AUC=0.8841
# Epoch=7, BatchID=120, Val_AUC=0.8664, Best_Val_AUC=0.8841
# Epoch=7, BatchID=140, Val_AUC=0.8511, Best_Val_AUC=0.8841
# Epoch=8, BatchID=0, Val_AUC=0.8515, Best_Val_AUC=0.8841
# Epoch=8, BatchID=20, Val_AUC=0.8374, Best_Val_AUC=0.8841
# Epoch=8, BatchID=40, Val_AUC=0.8427, Best_Val_AUC=0.8841
# Epoch=8, BatchID=60, Val_AUC=0.8512, Best_Val_AUC=0.8841
# Epoch=8, BatchID=80, Val_AUC=0.8669, Best_Val_AUC=0.8841
# Epoch=8, BatchID=100, Val_AUC=0.8619, Best_Val_AUC=0.8841
# Epoch=8, BatchID=120, Val_AUC=0.8577, Best_Val_AUC=0.8841
# Epoch=8, BatchID=140, Val_AUC=0.8428, Best_Val_AUC=0.8841
# Epoch=9, BatchID=0, Val_AUC=0.8575, Best_Val_AUC=0.8841
# Epoch=9, BatchID=20, Val_AUC=0.8573, Best_Val_AUC=0.8841
# Epoch=9, BatchID=40, Val_AUC=0.8608, Best_Val_AUC=0.8841
# Epoch=9, BatchID=60, Val_AUC=0.8629, Best_Val_AUC=0.8841
# Epoch=9, BatchID=80, Val_AUC=0.8504, Best_Val_AUC=0.8841
# Epoch=9, BatchID=100, Val_AUC=0.8709, Best_Val_AUC=0.8841
# Epoch=9, BatchID=120, Val_AUC=0.8567, Best_Val_AUC=0.8841
# Epoch=9, BatchID=140, Val_AUC=0.8605, Best_Val_AUC=0.8841
# Epoch=10, BatchID=0, Val_AUC=0.8666, Best_Val_AUC=0.8841
# Epoch=10, BatchID=20, Val_AUC=0.8482, Best_Val_AUC=0.8841
# Epoch=10, BatchID=40, Val_AUC=0.8617, Best_Val_AUC=0.8841
# Epoch=10, BatchID=60, Val_AUC=0.8615, Best_Val_AUC=0.8841
# Epoch=10, BatchID=80, Val_AUC=0.8658, Best_Val_AUC=0.8841
# Epoch=10, BatchID=100, Val_AUC=0.8698, Best_Val_AUC=0.8841
# Epoch=10, BatchID=120, Val_AUC=0.8700, Best_Val_AUC=0.8841
# Epoch=10, BatchID=140, Val_AUC=0.8746, Best_Val_AUC=0.8841
# Epoch=11, BatchID=0, Val_AUC=0.8728, Best_Val_AUC=0.8841
# Epoch=11, BatchID=20, Val_AUC=0.8727, Best_Val_AUC=0.8841
# Epoch=11, BatchID=40, Val_AUC=0.8769, Best_Val_AUC=0.8841
# Epoch=11, BatchID=60, Val_AUC=0.8772, Best_Val_AUC=0.8841
# Epoch=11, BatchID=80, Val_AUC=0.8810, Best_Val_AUC=0.8841
# Epoch=11, BatchID=100, Val_AUC=0.8832, Best_Val_AUC=0.8841
# Epoch=11, BatchID=120, Val_AUC=0.8826, Best_Val_AUC=0.8841
# Epoch=11, BatchID=140, Val_AUC=0.8835, Best_Val_AUC=0.8841
# Epoch=12, BatchID=0, Val_AUC=0.8836, Best_Val_AUC=0.8841
# Epoch=12, BatchID=20, Val_AUC=0.8831, Best_Val_AUC=0.8841
# Epoch=12, BatchID=40, Val_AUC=0.8808, Best_Val_AUC=0.8841
# Epoch=12, BatchID=60, Val_AUC=0.8838, Best_Val_AUC=0.8841
# Epoch=12, BatchID=80, Val_AUC=0.8851, Best_Val_AUC=0.8851
# Epoch=12, BatchID=100, Val_AUC=0.8843, Best_Val_AUC=0.8851
# Epoch=12, BatchID=120, Val_AUC=0.8847, Best_Val_AUC=0.8851
# Epoch=12, BatchID=140, Val_AUC=0.8851, Best_Val_AUC=0.8851
# Epoch=13, BatchID=0, Val_AUC=0.8843, Best_Val_AUC=0.8851
# Epoch=13, BatchID=20, Val_AUC=0.8852, Best_Val_AUC=0.8852
# Epoch=13, BatchID=40, Val_AUC=0.8877, Best_Val_AUC=0.8877
# Epoch=13, BatchID=60, Val_AUC=0.8846, Best_Val_AUC=0.8877
# Epoch=13, BatchID=80, Val_AUC=0.8827, Best_Val_AUC=0.8877
# Epoch=13, BatchID=100, Val_AUC=0.8847, Best_Val_AUC=0.8877
# Epoch=13, BatchID=120, Val_AUC=0.8852, Best_Val_AUC=0.8877
# Epoch=13, BatchID=140, Val_AUC=0.8868, Best_Val_AUC=0.8877
# Epoch=14, BatchID=0, Val_AUC=0.8862, Best_Val_AUC=0.8877
# Epoch=14, BatchID=20, Val_AUC=0.8854, Best_Val_AUC=0.8877
# Epoch=14, BatchID=40, Val_AUC=0.8833, Best_Val_AUC=0.8877
# Epoch=14, BatchID=60, Val_AUC=0.8858, Best_Val_AUC=0.8877
# Epoch=14, BatchID=80, Val_AUC=0.8856, Best_Val_AUC=0.8877
# Epoch=14, BatchID=100, Val_AUC=0.8841, Best_Val_AUC=0.8877
# Epoch=14, BatchID=120, Val_AUC=0.8825, Best_Val_AUC=0.8877
# Epoch=14, BatchID=140, Val_AUC=0.8813, Best_Val_AUC=0.8877
# Epoch=15, BatchID=0, Val_AUC=0.8814, Best_Val_AUC=0.8877
# Epoch=15, BatchID=20, Val_AUC=0.8821, Best_Val_AUC=0.8877
# Epoch=15, BatchID=40, Val_AUC=0.8800, Best_Val_AUC=0.8877
# Epoch=15, BatchID=60, Val_AUC=0.8799, Best_Val_AUC=0.8877
# Epoch=15, BatchID=80, Val_AUC=0.8826, Best_Val_AUC=0.8877
# Epoch=15, BatchID=100, Val_AUC=0.8805, Best_Val_AUC=0.8877
# Epoch=15, BatchID=120, Val_AUC=0.8784, Best_Val_AUC=0.8877
# Epoch=15, BatchID=140, Val_AUC=0.8749, Best_Val_AUC=0.8877
# Epoch=16, BatchID=0, Val_AUC=0.8774, Best_Val_AUC=0.8877
# Epoch=16, BatchID=20, Val_AUC=0.8806, Best_Val_AUC=0.8877
# Epoch=16, BatchID=40, Val_AUC=0.8794, Best_Val_AUC=0.8877
# Epoch=16, BatchID=60, Val_AUC=0.8764, Best_Val_AUC=0.8877
# Epoch=16, BatchID=80, Val_AUC=0.8747, Best_Val_AUC=0.8877
# Epoch=16, BatchID=100, Val_AUC=0.8744, Best_Val_AUC=0.8877
# Epoch=16, BatchID=120, Val_AUC=0.8779, Best_Val_AUC=0.8877
# Epoch=16, BatchID=140, Val_AUC=0.8782, Best_Val_AUC=0.8877
# Epoch=17, BatchID=0, Val_AUC=0.8762, Best_Val_AUC=0.8877
# Epoch=17, BatchID=20, Val_AUC=0.8775, Best_Val_AUC=0.8877
# Epoch=17, BatchID=40, Val_AUC=0.8750, Best_Val_AUC=0.8877
# Epoch=17, BatchID=60, Val_AUC=0.8756, Best_Val_AUC=0.8877
# Epoch=17, BatchID=80, Val_AUC=0.8746, Best_Val_AUC=0.8877
# Epoch=17, BatchID=100, Val_AUC=0.8770, Best_Val_AUC=0.8877
# Epoch=17, BatchID=120, Val_AUC=0.8775, Best_Val_AUC=0.8877
# Epoch=17, BatchID=140, Val_AUC=0.8480, Best_Val_AUC=0.8877
# Epoch=18, BatchID=0, Val_AUC=0.8611, Best_Val_AUC=0.8877
# Epoch=18, BatchID=20, Val_AUC=0.8725, Best_Val_AUC=0.8877
# Epoch=18, BatchID=40, Val_AUC=0.8645, Best_Val_AUC=0.8877
# Epoch=18, BatchID=60, Val_AUC=0.8700, Best_Val_AUC=0.8877
# Epoch=18, BatchID=80, Val_AUC=0.8769, Best_Val_AUC=0.8877
# Epoch=18, BatchID=100, Val_AUC=0.8720, Best_Val_AUC=0.8877
# Epoch=18, BatchID=120, Val_AUC=0.8780, Best_Val_AUC=0.8877
# Epoch=18, BatchID=140, Val_AUC=0.8669, Best_Val_AUC=0.8877
# Epoch=19, BatchID=0, Val_AUC=0.8709, Best_Val_AUC=0.8877
# Epoch=19, BatchID=20, Val_AUC=0.8641, Best_Val_AUC=0.8877
# Epoch=19, BatchID=40, Val_AUC=0.8659, Best_Val_AUC=0.8877
# Epoch=19, BatchID=60, Val_AUC=0.8662, Best_Val_AUC=0.8877
# Epoch=19, BatchID=80, Val_AUC=0.8648, Best_Val_AUC=0.8877
# Epoch=19, BatchID=100, Val_AUC=0.8739, Best_Val_AUC=0.8877
# Epoch=19, BatchID=120, Val_AUC=0.8716, Best_Val_AUC=0.8877
# Epoch=19, BatchID=140, Val_AUC=0.8744, Best_Val_AUC=0.8877
# Epoch=20, BatchID=0, Val_AUC=0.8723, Best_Val_AUC=0.8877
# Epoch=20, BatchID=20, Val_AUC=0.8670, Best_Val_AUC=0.8877
# Epoch=20, BatchID=40, Val_AUC=0.8590, Best_Val_AUC=0.8877
# Epoch=20, BatchID=60, Val_AUC=0.8631, Best_Val_AUC=0.8877
# Epoch=20, BatchID=80, Val_AUC=0.8656, Best_Val_AUC=0.8877
# Epoch=20, BatchID=100, Val_AUC=0.6788, Best_Val_AUC=0.8877
# Epoch=20, BatchID=120, Val_AUC=0.8702, Best_Val_AUC=0.8877
# Epoch=20, BatchID=140, Val_AUC=0.8516, Best_Val_AUC=0.8877
# Epoch=21, BatchID=0, Val_AUC=0.8230, Best_Val_AUC=0.8877
# Epoch=21, BatchID=20, Val_AUC=0.8555, Best_Val_AUC=0.8877
# Epoch=21, BatchID=40, Val_AUC=0.8373, Best_Val_AUC=0.8877
# Epoch=21, BatchID=60, Val_AUC=0.8227, Best_Val_AUC=0.8877
# Epoch=21, BatchID=80, Val_AUC=0.8357, Best_Val_AUC=0.8877
# Epoch=21, BatchID=100, Val_AUC=0.8070, Best_Val_AUC=0.8877
# Epoch=21, BatchID=120, Val_AUC=0.8730, Best_Val_AUC=0.8877
# Epoch=21, BatchID=140, Val_AUC=0.8571, Best_Val_AUC=0.8877
# Epoch=22, BatchID=0, Val_AUC=0.8540, Best_Val_AUC=0.8877
# Epoch=22, BatchID=20, Val_AUC=0.8695, Best_Val_AUC=0.8877
# Epoch=22, BatchID=40, Val_AUC=0.8542, Best_Val_AUC=0.8877
# Epoch=22, BatchID=60, Val_AUC=0.8408, Best_Val_AUC=0.8877
# Epoch=22, BatchID=80, Val_AUC=0.8603, Best_Val_AUC=0.8877
# Epoch=22, BatchID=100, Val_AUC=0.8624, Best_Val_AUC=0.8877
# Epoch=22, BatchID=120, Val_AUC=0.8684, Best_Val_AUC=0.8877
# Epoch=22, BatchID=140, Val_AUC=0.7940, Best_Val_AUC=0.8877
# Epoch=23, BatchID=0, Val_AUC=0.8265, Best_Val_AUC=0.8877
# Epoch=23, BatchID=20, Val_AUC=0.8248, Best_Val_AUC=0.8877
# Epoch=23, BatchID=40, Val_AUC=0.8615, Best_Val_AUC=0.8877
# Epoch=23, BatchID=60, Val_AUC=0.8436, Best_Val_AUC=0.8877
# Epoch=23, BatchID=80, Val_AUC=0.8552, Best_Val_AUC=0.8877
# Epoch=23, BatchID=100, Val_AUC=0.8598, Best_Val_AUC=0.8877
# Epoch=23, BatchID=120, Val_AUC=0.8451, Best_Val_AUC=0.8877
# Epoch=23, BatchID=140, Val_AUC=0.8451, Best_Val_AUC=0.8877
# Epoch=24, BatchID=0, Val_AUC=0.8431, Best_Val_AUC=0.8877
# Epoch=24, BatchID=20, Val_AUC=0.8462, Best_Val_AUC=0.8877
# Epoch=24, BatchID=40, Val_AUC=0.8273, Best_Val_AUC=0.8877
# Epoch=24, BatchID=60, Val_AUC=0.8495, Best_Val_AUC=0.8877
# Epoch=24, BatchID=80, Val_AUC=0.8464, Best_Val_AUC=0.8877
# Epoch=24, BatchID=100, Val_AUC=0.8430, Best_Val_AUC=0.8877
# Epoch=24, BatchID=120, Val_AUC=0.8467, Best_Val_AUC=0.8877
# Epoch=24, BatchID=140, Val_AUC=0.8691, Best_Val_AUC=0.8877
# Epoch=25, BatchID=0, Val_AUC=0.8728, Best_Val_AUC=0.8877
# Epoch=25, BatchID=20, Val_AUC=0.8635, Best_Val_AUC=0.8877
# Epoch=25, BatchID=40, Val_AUC=0.8634, Best_Val_AUC=0.8877
# Epoch=25, BatchID=60, Val_AUC=0.8681, Best_Val_AUC=0.8877
# Epoch=25, BatchID=80, Val_AUC=0.8339, Best_Val_AUC=0.8877
# Epoch=25, BatchID=100, Val_AUC=0.8583, Best_Val_AUC=0.8877
# Epoch=25, BatchID=120, Val_AUC=0.8666, Best_Val_AUC=0.8877
# Epoch=25, BatchID=140, Val_AUC=0.8654, Best_Val_AUC=0.8877
# Epoch=26, BatchID=0, Val_AUC=0.8659, Best_Val_AUC=0.8877
# Epoch=26, BatchID=20, Val_AUC=0.8688, Best_Val_AUC=0.8877
# Epoch=26, BatchID=40, Val_AUC=0.8718, Best_Val_AUC=0.8877
# Epoch=26, BatchID=60, Val_AUC=0.8735, Best_Val_AUC=0.8877
# Epoch=26, BatchID=80, Val_AUC=0.8720, Best_Val_AUC=0.8877
# Epoch=26, BatchID=100, Val_AUC=0.8523, Best_Val_AUC=0.8877
# Epoch=26, BatchID=120, Val_AUC=0.8603, Best_Val_AUC=0.8877
# Epoch=26, BatchID=140, Val_AUC=0.8534, Best_Val_AUC=0.8877
# Epoch=27, BatchID=0, Val_AUC=0.8559, Best_Val_AUC=0.8877
# Epoch=27, BatchID=20, Val_AUC=0.8589, Best_Val_AUC=0.8877
# Epoch=27, BatchID=40, Val_AUC=0.8700, Best_Val_AUC=0.8877
# Epoch=27, BatchID=60, Val_AUC=0.8663, Best_Val_AUC=0.8877
# Epoch=27, BatchID=80, Val_AUC=0.8714, Best_Val_AUC=0.8877
# Epoch=27, BatchID=100, Val_AUC=0.8789, Best_Val_AUC=0.8877
# Epoch=27, BatchID=120, Val_AUC=0.8735, Best_Val_AUC=0.8877
# Epoch=27, BatchID=140, Val_AUC=0.8700, Best_Val_AUC=0.8877
# Epoch=28, BatchID=0, Val_AUC=0.8710, Best_Val_AUC=0.8877
# Epoch=28, BatchID=20, Val_AUC=0.8697, Best_Val_AUC=0.8877
# Epoch=28, BatchID=40, Val_AUC=0.8729, Best_Val_AUC=0.8877
# Epoch=28, BatchID=60, Val_AUC=0.8711, Best_Val_AUC=0.8877
# Epoch=28, BatchID=80, Val_AUC=0.8707, Best_Val_AUC=0.8877
# Epoch=28, BatchID=100, Val_AUC=0.8697, Best_Val_AUC=0.8877
# Epoch=28, BatchID=120, Val_AUC=0.8718, Best_Val_AUC=0.8877
# Epoch=28, BatchID=140, Val_AUC=0.8724, Best_Val_AUC=0.8877
# Epoch=29, BatchID=0, Val_AUC=0.8698, Best_Val_AUC=0.8877
# Epoch=29, BatchID=20, Val_AUC=0.8703, Best_Val_AUC=0.8877
# Epoch=29, BatchID=40, Val_AUC=0.8706, Best_Val_AUC=0.8877
# Epoch=29, BatchID=60, Val_AUC=0.8713, Best_Val_AUC=0.8877
# Epoch=29, BatchID=80, Val_AUC=0.8700, Best_Val_AUC=0.8877
# Epoch=29, BatchID=100, Val_AUC=0.8739, Best_Val_AUC=0.8877
# Epoch=29, BatchID=120, Val_AUC=0.8730, Best_Val_AUC=0.8877
# Epoch=29, BatchID=140, Val_AUC=0.8718, Best_Val_AUC=0.8877
# Epoch=30, BatchID=0, Val_AUC=0.8719, Best_Val_AUC=0.8877
# Epoch=30, BatchID=20, Val_AUC=0.8755, Best_Val_AUC=0.8877
# Epoch=30, BatchID=40, Val_AUC=0.8719, Best_Val_AUC=0.8877
# Epoch=30, BatchID=60, Val_AUC=0.8710, Best_Val_AUC=0.8877
# Epoch=30, BatchID=80, Val_AUC=0.8709, Best_Val_AUC=0.8877
# Epoch=30, BatchID=100, Val_AUC=0.8693, Best_Val_AUC=0.8877
# Epoch=30, BatchID=120, Val_AUC=0.8730, Best_Val_AUC=0.8877
# Epoch=30, BatchID=140, Val_AUC=0.8624, Best_Val_AUC=0.8877
# Epoch=31, BatchID=0, Val_AUC=0.8671, Best_Val_AUC=0.8877
# Epoch=31, BatchID=20, Val_AUC=0.8702, Best_Val_AUC=0.8877
# Epoch=31, BatchID=40, Val_AUC=0.8713, Best_Val_AUC=0.8877
# Epoch=31, BatchID=60, Val_AUC=0.8707, Best_Val_AUC=0.8877
# Epoch=31, BatchID=80, Val_AUC=0.8683, Best_Val_AUC=0.8877
# Epoch=31, BatchID=100, Val_AUC=0.8732, Best_Val_AUC=0.8877
# Epoch=31, BatchID=120, Val_AUC=0.8706, Best_Val_AUC=0.8877
# Epoch=31, BatchID=140, Val_AUC=0.8732, Best_Val_AUC=0.8877
# Epoch=32, BatchID=0, Val_AUC=0.8723, Best_Val_AUC=0.8877
# Epoch=32, BatchID=20, Val_AUC=0.8707, Best_Val_AUC=0.8877
# Epoch=32, BatchID=40, Val_AUC=0.8686, Best_Val_AUC=0.8877
# Epoch=32, BatchID=60, Val_AUC=0.8694, Best_Val_AUC=0.8877
# Epoch=32, BatchID=80, Val_AUC=0.8695, Best_Val_AUC=0.8877
# Epoch=32, BatchID=100, Val_AUC=0.8666, Best_Val_AUC=0.8877
# Epoch=32, BatchID=120, Val_AUC=0.8652, Best_Val_AUC=0.8877
# Epoch=32, BatchID=140, Val_AUC=0.8680, Best_Val_AUC=0.8877
# Epoch=33, BatchID=0, Val_AUC=0.8669, Best_Val_AUC=0.8877
# Epoch=33, BatchID=20, Val_AUC=0.8710, Best_Val_AUC=0.8877
# Epoch=33, BatchID=40, Val_AUC=0.8684, Best_Val_AUC=0.8877
# Epoch=33, BatchID=60, Val_AUC=0.8709, Best_Val_AUC=0.8877
# Epoch=33, BatchID=80, Val_AUC=0.8722, Best_Val_AUC=0.8877
# Epoch=33, BatchID=100, Val_AUC=0.8674, Best_Val_AUC=0.8877
# Epoch=33, BatchID=120, Val_AUC=0.8685, Best_Val_AUC=0.8877
# Epoch=33, BatchID=140, Val_AUC=0.8608, Best_Val_AUC=0.8877
# Epoch=34, BatchID=0, Val_AUC=0.8666, Best_Val_AUC=0.8877
# Epoch=34, BatchID=20, Val_AUC=0.8682, Best_Val_AUC=0.8877
# Epoch=34, BatchID=40, Val_AUC=0.8673, Best_Val_AUC=0.8877
# Epoch=34, BatchID=60, Val_AUC=0.8686, Best_Val_AUC=0.8877
# Epoch=34, BatchID=80, Val_AUC=0.8712, Best_Val_AUC=0.8877
# Epoch=34, BatchID=100, Val_AUC=0.8711, Best_Val_AUC=0.8877
# Epoch=34, BatchID=120, Val_AUC=0.8678, Best_Val_AUC=0.8877
# Epoch=34, BatchID=140, Val_AUC=0.8699, Best_Val_AUC=0.8877
# Epoch=35, BatchID=0, Val_AUC=0.8676, Best_Val_AUC=0.8877
# Epoch=35, BatchID=20, Val_AUC=0.8678, Best_Val_AUC=0.8877
# Epoch=35, BatchID=40, Val_AUC=0.8664, Best_Val_AUC=0.8877
# Epoch=35, BatchID=60, Val_AUC=0.8674, Best_Val_AUC=0.8877
# Epoch=35, BatchID=80, Val_AUC=0.8699, Best_Val_AUC=0.8877
# Epoch=35, BatchID=100, Val_AUC=0.8663, Best_Val_AUC=0.8877
# Epoch=35, BatchID=120, Val_AUC=0.8674, Best_Val_AUC=0.8877
# Epoch=35, BatchID=140, Val_AUC=0.8690, Best_Val_AUC=0.8877
# Epoch=36, BatchID=0, Val_AUC=0.8657, Best_Val_AUC=0.8877
# Epoch=36, BatchID=20, Val_AUC=0.8689, Best_Val_AUC=0.8877
# Epoch=36, BatchID=40, Val_AUC=0.8683, Best_Val_AUC=0.8877
# Epoch=36, BatchID=60, Val_AUC=0.8714, Best_Val_AUC=0.8877
# Epoch=36, BatchID=80, Val_AUC=0.8655, Best_Val_AUC=0.8877
# Epoch=36, BatchID=100, Val_AUC=0.8720, Best_Val_AUC=0.8877
# Epoch=36, BatchID=120, Val_AUC=0.8709, Best_Val_AUC=0.8877
# Epoch=36, BatchID=140, Val_AUC=0.8680, Best_Val_AUC=0.8877
# Epoch=37, BatchID=0, Val_AUC=0.8674, Best_Val_AUC=0.8877
# Epoch=37, BatchID=20, Val_AUC=0.8758, Best_Val_AUC=0.8877
# Epoch=37, BatchID=40, Val_AUC=0.8750, Best_Val_AUC=0.8877
# Epoch=37, BatchID=60, Val_AUC=0.8753, Best_Val_AUC=0.8877
# Epoch=37, BatchID=80, Val_AUC=0.8711, Best_Val_AUC=0.8877
# Epoch=37, BatchID=100, Val_AUC=0.8719, Best_Val_AUC=0.8877
# Epoch=37, BatchID=120, Val_AUC=0.8730, Best_Val_AUC=0.8877
# Epoch=37, BatchID=140, Val_AUC=0.8726, Best_Val_AUC=0.8877
# Epoch=38, BatchID=0, Val_AUC=0.8709, Best_Val_AUC=0.8877
# Epoch=38, BatchID=20, Val_AUC=0.8674, Best_Val_AUC=0.8877
# Epoch=38, BatchID=40, Val_AUC=0.8700, Best_Val_AUC=0.8877
# Epoch=38, BatchID=60, Val_AUC=0.8679, Best_Val_AUC=0.8877
# Epoch=38, BatchID=80, Val_AUC=0.8714, Best_Val_AUC=0.8877
# Epoch=38, BatchID=100, Val_AUC=0.8713, Best_Val_AUC=0.8877
# Epoch=38, BatchID=120, Val_AUC=0.8716, Best_Val_AUC=0.8877
# Epoch=38, BatchID=140, Val_AUC=0.8674, Best_Val_AUC=0.8877
# Epoch=39, BatchID=0, Val_AUC=0.8680, Best_Val_AUC=0.8877
# Epoch=39, BatchID=20, Val_AUC=0.8726, Best_Val_AUC=0.8877
# Epoch=39, BatchID=40, Val_AUC=0.8717, Best_Val_AUC=0.8877
# Epoch=39, BatchID=60, Val_AUC=0.8648, Best_Val_AUC=0.8877
# Epoch=39, BatchID=80, Val_AUC=0.8628, Best_Val_AUC=0.8877
# Epoch=39, BatchID=100, Val_AUC=0.8591, Best_Val_AUC=0.8877
# Epoch=39, BatchID=120, Val_AUC=0.8582, Best_Val_AUC=0.8877
# Epoch=39, BatchID=140, Val_AUC=0.8615, Best_Val_AUC=0.8877

# %%
 # Testing
 ckpt =  torch.load("nodule_model.pt")
 model.load_state_dict(ckpt)
 model.eval()
 best_val_auc = 0
 with torch.no_grad():    
      test_pred = []
      test_true = [] 
      for jdx, (data, targets, _) in enumerate(testloader):
          test_data, test_labels = data, targets
          test_data = test_data.cuda()
          y_pred = model(test_data)
          y_pred = torch.sigmoid(y_pred)
          test_pred.append(y_pred.cpu().detach().numpy())
          test_true.append(test_labels.numpy())

      test_true = np.concatenate(test_true)
      test_pred = np.concatenate(test_pred)
      test_auc_mean = auc_roc_score(test_true, test_pred)[0]
      model.train()

      if best_val_auc < test_auc_mean:
         best_val_auc = test_auc_mean
#          torch.save(model.state_dict(), 'aucm_chest_model.pt')

      print ('Test result   ::::::::   Test_AUC = %.4f'%(test_auc_mean))
# Out:
# Test result   ::::::::   Test_AUC = 0.8877
